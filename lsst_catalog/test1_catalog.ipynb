# %%
import matplotlib.pyplot as plt
from astropy.cosmology import FlatLambdaCDM
from astropy.units import Quantity
from slsim.Lenses.lens_pop import LensPop
from slsim.Plots.lens_plots import LensingPlots
import numpy as np
import corner
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 import matplotlib.pyplot as plt
#       2 from astropy.cosmology import FlatLambdaCDM
#       3 from astropy.units import Quantity
# ----> 4 from slsim.Lenses.lens_pop import LensPop
#       5 from slsim.Plots.lens_plots import LensingPlots
#       6 import numpy as np
#       7 import corner
#
# File /opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/slsim/Lenses/lens_pop.py:3
#       1 import numpy as np
# ----> 3 from slsim.Lenses.lens import Lens
#       4 from typing import Optional
#       5 from astropy.cosmology import Cosmology
#
# File /opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/slsim/Lenses/lens.py:25
#      19 from slsim.ImageSimulation.image_quality_lenstronomy import (
#      20     kwargs_single_band,
#      21     get_observatory,
#      22 )
#      23 from scipy.ndimage import label
# ---> 25 from slsim.Lenses.lensed_system_base import LensedSystemBase
#      26 from slsim.Deflectors.deflector import JAX_PROFILES
#      27 import pandas as pd
#
# File /opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/slsim/Lenses/lensed_system_base.py:3
#       1 from abc import ABC, abstractmethod
#       2 from slsim.LOS.los_individual import LOSIndividual
# ----> 3 from slsim.Sources.source import Source
#       6 class LensedSystemBase(ABC):
#       7     """Abstract Base class to create a lens system with all lensing properties
#       8     required to render populations."""
#
# File /opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/slsim/Sources/__init__.py:1
# ----> 1 from slsim.Sources.SourcePopulation.galaxies import Galaxies
#       2 from slsim.Sources.SourcePopulation.scotch_sources import ScotchSources
#       3 from slsim.Sources.SourcePopulation.point_sources import PointSources
#
# File /opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/slsim/Sources/SourcePopulation/galaxies.py:16
#       7 from slsim.Util.param_util import (
#       8     average_angular_size,
#       9     axis_ratio,
#    (...)     13     galaxy_size,
#      14 )
#      15 from astropy import units as u
# ---> 16 from slsim.Sources.source import Source
#      17 import os
#      20 # TODO: Use type to determine galaxy_list type
#
# File /opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/slsim/Sources/source.py:1
# ----> 1 from slsim.Sources.SourceTypes.point_plus_extended_source import PointPlusExtendedSource
#       3 _SUPPORTED_POINT_SOURCES = ["supernova", "quasar", "general_lightcurve"]
#       4 _SUPPORTED_EXTENDED_SOURCES = [
#       5     "single_sersic",
#       6     "double_sersic",
#       7     "catalog_source",
#       8     "interpolated",
#       9 ]
#
# File /opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/slsim/Sources/SourceTypes/point_plus_extended_source.py:1
# ----> 1 from slsim.Sources.SourceTypes.point_source import PointSource
#       2 from slsim.Sources.SourceTypes.extended_source import ExtendedSource
#       5 class PointPlusExtendedSource(PointSource, ExtendedSource):
#
# File /opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/slsim/Sources/SourceTypes/point_source.py:1
# ----> 1 from slsim.Sources.SourceTypes.supernova_event import SupernovaEvent
#       2 from slsim.Sources.SourceTypes.quasar import Quasar
#       3 from slsim.Sources.SourceTypes.general_lightcurve import GeneralLightCurve
#
# File /opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/slsim/Sources/SourceTypes/supernova_event.py:2
#       1 import warnings
# ----> 2 from slsim.Sources.Supernovae import random_supernovae
#       3 from slsim.Sources.SourceTypes.source_base import SourceBase
#       4 from slsim.ImageSimulation.image_quality_lenstronomy import get_all_supported_bands
#
# File /opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/slsim/Sources/Supernovae/random_supernovae.py:3
#       1 import os
#       2 import numpy as np
# ----> 3 import sncosmo
#       4 from astropy import cosmology
#       5 from slsim.Sources.Supernovae.supernova import Supernova
#
# File /opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/sncosmo/__init__.py:147
#     145 from .magsystems import *
#     146 from .spectrum import *
# --> 147 from .models import *
#     148 from .io import *
#     149 from .snanaio import *
#
# File /opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/sncosmo/models.py:28
#      23 from .io import (
#      24     read_griddata_ascii, read_griddata_fits,
#      25     read_multivector_griddata_ascii
#      26 )
#      27 from .magsystems import get_magsystem
# ---> 28 from .salt2utils import BicubicInterpolator, SALT2ColorLaw
#      29 from .utils import integration_grid, sine_interp
#      31 __all__ = ['get_source', 'Source', 'TimeSeriesSource', 'StretchSource',
#      32            'SUGARSource', 'SALT2Source', 'SALT3Source', 'MLCS2k2Source',
#      33            'SNEMOSource', 'Model', 'PropagationEffect', 'CCM89Dust',
#      34            'OD94Dust', 'F99Dust']
#
# ImportError: dlopen(/opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/sncosmo/salt2utils.cpython-311-darwin.so, 0x0002): tried: '/opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/sncosmo/salt2utils.cpython-311-darwin.so' (duplicate LC_RPATH '/Users/juananconaflores/.pyenv/versions/3.11.10/lib'), '/System/Volumes/Preboot/Cryptexes/OS/opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/sncosmo/salt2utils.cpython-311-darwin.so' (no such file), '/opt/anaconda3/envs/slsim_test/lib/python3.11/site-packages/sncosmo/salt2utils.cpython-311-darwin.so' (duplicate LC_RPATH '/Users/juananconaflores/.pyenv/versions/3.11.10/lib')
